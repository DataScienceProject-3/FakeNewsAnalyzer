# %%
import tweepy
import csv
import json
from config import (consumer_key, consumer_secret,
                    access_token, access_token_secret)
import wget
from bson import ObjectId # For ObjectId to work
from pymongo import MongoClient
import pandas as pd
from datetime import datetime
import numpy as np
import time

# %%
uri = "mongodb://newsdata:ZG4cTh2XbyUpkiVggEcQ6lL6UEC32iJThy4eZrO9RLY1suKiXdUNrqi5pzrqzqNvUsdO9xAxjhyFfNfNVoBeXA==@newsdata.documents.azure.com:10255/?ssl=true&replicaSet=globaldb"
client = MongoClient(uri)
db = client.fakenewsdb
politico_facts_data_table = db.politico_facts_data
print(politico_facts_data_table.find_one())
# Out:
# {'_id': ObjectId('5c23d50044925f3eb8d1a2ef'), 'Date': 'on Sunday, December 23rd, 2018', 'Meter': 'Half-True', 'Source': 'Garry McCarthy', 'Statement': '"There was almost a 70 percent reduction in police-related shootings under my tenure because of training, supervision and policy decisions."\r\n', 'Statement_url': '/illinois/statements/2018/dec/23/garry-mccarthy/did-police-shootings-plunge-under-mccarthys-leader/', 'Fact': "The numbers fell, but that doesn't mean he can take all the credit", 'Source_Url': '/personalities/garry-mccarthy/statements/byruling/half-true/'}

# %%
fakenews_datatable = db.fakenews_data
print(fakenews_datatable.find_one())
# Out:
# {'_id': ObjectId('5c3445ffe8a490580c567e3c'), 'id': 'politifact14927', 'text_content': {'movies': [], 'images': ['https://ichef.bbci.co.uk/news/1024/media/images/71100000/jpg/_71100784_5c13818a-b5e6-4be8-a7dd-fc65d00632d7.jpg', 'http://ssc.api.bbc.com/?c1=2&c2=19293874&ns_site=bbc&name=news.av.entertainment-arts-24934979.oprah-winfrey-the-butler-racism-and-obama', 'https://news.bbcimg.co.uk/media/images/65840000/jpg/_65840685_hi017217364.jpg', 'https://news.bbcimg.co.uk/media/images/69254000/jpg/_69254318_69254317.jpg', 'https://news.bbcimg.co.uk/media/images/69265000/jpg/_69265117_69265116.jpg', 'https://ichef.bbci.co.uk/news/640/media/images/71100000/jpg/_71100780_71100779.jpg', 'https://sa.bbc.co.uk/bbc/bbc/s?name=news.entertainment_and_arts.media_asset.24934979.page&ml_name=webmodule&ml_version=95&blq_js_enabled=0&blq_s=4d&blq_r=2.7&blq_v=default&blq_e=pal&cps_asset_id=24934979&page_type=media_asset&section=%2Fnews%2Fentertainment_and_arts&first_pub=2013-11-13T18%3A25%3A48%2B00%3A00&last_editorial_update=2013-11-13T21%3A01%3A58%2B00%3A00&curie=3392de64-26bd-2645-a8c7-78f22d4878fb&title=Oprah+Winfrey%3A+The+Butler%2C+racism+and+Obama&has_video=1&cps_media_type=video&for_nation=us&app_version=1.243.0&bbc_site=news&pal_route=betamax-map-seo&app_type=responsive&language=en-GB&pal_webapp=betamax&prod_name=news&app_name=news', 'http://static.bbci.co.uk/frameworks/barlesque/3.22.55/orb/4/img/bbc-blocks-dark.png', 'https://ichef.bbci.co.uk/news/200/media/images/71100000/jpg/_71100784_5c13818a-b5e6-4be8-a7dd-fc65d00632d7.jpg'], 'top_img': 'https://ichef.bbci.co.uk/news/1024/media/images/71100000/jpg/_71100784_5c13818a-b5e6-4be8-a7dd-fc65d00632d7.jpg', 'summary': '', 'keywords': [], 'source': 'http://www.bbc.com', 'text': 'Video\n\nAmerican broadcaster and actress Oprah Winfrey said there was a whole generation of racist people who were "born and bred and marinated" in racism who would never change their ways, but that would die out.\n\nShe spoke to the BBC\'s Will Gompertz while in the UK to promote her new film The Butler, in which she plays Gloria Gaines, the wife of a White House butler.', 'authors': [], 'meta_data': {'mobile-web-app-capable': 'yes', 'CPS_AUDIENCE': 'US', 'apple-mobile-web-app-title': 'BBC News', 'twitter': {'site': '@BBCWorld', 'title': 'Winfrey: The Butler, racism and Obama', 'card': 'summary_large_image', 'creator': '@BBCWorld', 'description': 'American broadcaster and actress Oprah Winfrey said there was a whole generation of racist people who were "born and bred and marinated" in racism who would never change their ways, but that would die out.', 'image': {'alt': 'Oprah Winfrey', 'src': 'https://ichef.bbci.co.uk/news/1024/media/images/71100000/jpg/_71100784_5c13818a-b5e6-4be8-a7dd-fc65d00632d7.jpg'}, 'domain': 'www.bbc.com'}, 'fb': {'admins': 100004154058350, 'pages': '1143803202301544,317278538359186,1392506827668140,742734325867560,185246968166196,156060587793370,137920769558355,193435954068976,21263239760,156400551056385,929399697073756,154344434967,228735667216,80758950658,260212261199,294662213128,1086451581439054,283348121682053,295830058648,239931389545417,304314573046,310719525611571,647687225371774,1159932557403143,286567251709437,1731770190373618,125309456546,163571453661989,285361880228,512423982152360,238003846549831,176663550714,260967092113,118450564909230,100978706649892,15286229625,122103087870579,120655094632228,102814153147070,124715648647,153132638110668,150467675018739', 'app_id': 1609039196070050}, 'viewport': 'width=device-width, initial-scale=1, user-scalable=1', 'msapplication-TileImage': 'BBC News', 'og': {'locale': 'en_GB', 'title': 'Winfrey: The Butler, racism and Obama', 'site_name': 'BBC News', 'type': 'website', 'url': 'https://www.bbc.com/news/av/entertainment-arts-24934979/oprah-winfrey-the-butler-racism-and-obama', 'description': 'American broadcaster and actress Oprah Winfrey said there was a whole generation of racist people who were "born and bred and marinated" in racism ...

# %%
tweet = fakenews_datatable.find_one()['tweets']

# %%
tweet
# Out:
# [{'reply': [],
#   'text': 'Breaking News - VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress O... http://bbc.in/1cp6nkD  - BBCBreaking',
#   'created_at': 1384377137,
#   'retweet': [],
#   'user_name': 'AfricainLive',
#   'likes': [],
#   'tweet_id': 400732875898638336,
#   'user_id': 1308616477},
#  {'reply': [],
#   'text': 'BBC News: VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey sai... http://bbc.in/1cp6pZW  #fb',
#   'created_at': 1384377137,
#   'retweet': [],
#   'user_name': 'Angelus1701',
#   'likes': [],
#   'tweet_id': 400732874678087680,
#   'user_id': 135092899},
#  {'reply': [],
#   'text': 'Breaking News - VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress O... http://bbc.in/1cp6nkD  - BBCBreaking',
#   'created_at': 1384377137,
#   'retweet': [],
#   'user_name': 'lomeinlive',
#   'likes': [],
#   'tweet_id': 400732874074120192,
#   'user_id': 976772936},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/HYKdMw ',
#   'created_at': 1384377154,
#   'retweet': [],
#   'user_name': 'BBCNewsUKfeed',
#   'likes': [],
#   'tweet_id': 400732945780342784,
#   'user_id': 389054819},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1GMB ',
#   'created_at': 1384377201,
#   'retweet': [],
#   'user_name': 'hrachmatullah',
#   'likes': [],
#   'tweet_id': 400733142182395905,
#   'user_id': 758648611},
#  {'reply': [],
#   'text': 'Huge Network |  Watch |  VIDEO: Winfrey: The Butler, racism and Obama http://bit.ly/1gKQ7Qy  #TopNews #BBC #News #HNN',
#   'created_at': 1384377239,
#   'retweet': [],
#   'user_name': 'HugeNetwork_EN',
#   'likes': [],
#   'tweet_id': 400733305118552064,
#   'user_id': 494026634},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1H7J ',
#   'created_at': 1384377262,
#   'retweet': [],
#   'user_name': 'UsmanAnwar78',
#   'likes': [],
#   'tweet_id': 400733400970956800,
#   'user_id': 22473015},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1HZ1  - @BBCNews #INW',
#   'created_at': 1384377310,
#   'retweet': [],
#   'user_name': 'IntNewsWatch',
#   'likes': [],
#   'tweet_id': 400733600028442624,
#   'user_id': 66286419},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said ther... http://bbc.in/1cp6nkS  #KayHem',
#   'created_at': 1384377323,
#   'retweet': [],
#   'user_name': 'TheReal_KayHem',
#   'likes': [],
#   'tweet_id': 400733657721085953,
#   'user_id': 155139830},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Hkm ',
#   'created_at': 1384377324,
#   'retweet': [],
#   'user_name': 'legallb',
#   'likes': [],
#   'tweet_id': 400733660548046849,
#   'user_id': 15307496},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Hkn  #bbc',
#   'created_at': 1384377325,
#   'retweet': [],
#   'user_name': 'speedarticles',
#   'likes': [],
#   'tweet_id': 400733665728024577,
#   'user_id': 252487102},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a... http://j.mp/18t2bxI ',
#   'created_at': 1384377328,
#   'retweet': [],
#   'user_name': 'neutralnews',
#   'likes': [],
#   'tweet_id': 400733678474518528,
#   'user_id': 244317966},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Hnl ',
#   'created_at': 1384377329,
#   'retweet': [],
#   'user_name': 'triomacan20005',
#   'likes': [],
#   'tweet_id': 400733682006097920,
#   'user_id': 976542686},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377329,
#   'retweet': [],
#   'user_name': 'Bigdada6',
#   'likes': [],
#   'tweet_id': 400733680508747776,
#   'user_id': 545598800},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Wi... http://bbc.in/1cp6nkS  http://bit.ly/13xs1kw ',
#   'created_at': 1384377333,
#   'retweet': [],
#   'user_name': 'chasesfeed',
#   'likes': [],
#   'tweet_id': 400733699248910336,
#   'user_id': 266876176},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1cp6nkS ',
#   'created_at': 1384377334,
#   'retweet': [],
#   'user_name': 'exitcrew91',
#   'likes': [],
#   'tweet_id': 400733703279620096,
#   'user_id': 702031146},
#  {'reply': [],
#   'text': '#AdityaRamadana VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Ht4 ',
#   'created_at': 1384377335,
#   'retweet': [],
#   'user_name': 'Reinayg721',
#   'likes': [],
#   'tweet_id': 400733706643443712,
#   'user_id': 544818165},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6WLf ',
#   'created_at': 1384377340,
#   'retweet': [],
#   'user_name': 'just_asepkurnia',
#   'likes': [],
#   'tweet_id': 400733725366816769,
#   'user_id': 753804608},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377342,
#   'retweet': [],
#   'user_name': 'sweetboyidunnu',
#   'likes': [],
#   'tweet_id': 400733734330060800,
#   'user_id': 250693957},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Hzf ',
#   'created_at': 1384377347,
#   'retweet': [],
#   'user_name': 'SwissNetInc',
#   'likes': [],
#   'tweet_id': 400733757423906816,
#   'user_id': 128222457},
#  {'reply': [],
#   'text': '[BBC] VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said... http://bbc.in/1cp6Xiy  #Rennd',
#   'created_at': 1384377352,
#   'retweet': [],
#   'user_name': 'Rennd_',
#   'likes': [],
#   'tweet_id': 400733776080154624,
#   'user_id': 945688650},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1J4j ',
#   'created_at': 1384377353,
#   'retweet': [],
#   'user_name': 'jamesgreid',
#   'likes': [],
#   'tweet_id': 400733780152827904,
#   'user_id': 813064693},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377359,
#   'retweet': [],
#   'user_name': 'sirehorlamz',
#   'likes': [],
#   'tweet_id': 400733807340318720,
#   'user_id': 882431395},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377371,
#   'retweet': [],
#   'user_name': 'Daily_Newss',
#   'likes': [],
#   'tweet_id': 400733858368212992,
#   'user_id': 632511744},
#  {'reply': [],
#   'text': '#bentozy VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey sa... http://bbc.in/1cp6nkS  #news',
#   'created_at': 1384377376,
#   'retweet': [],
#   'user_name': 'bentozy',
#   'likes': [],
#   'tweet_id': 400733879109025794,
#   'user_id': 635338782},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377384,
#   'retweet': [],
#   'user_name': 'LatestNews100',
#   'likes': [],
#   'tweet_id': 400733912483127296,
#   'user_id': 1610261773},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377395,
#   'retweet': [],
#   'user_name': 'binbas_jibril',
#   'likes': [],
#   'tweet_id': 400733959127965697,
#   'user_id': 312647115},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377401,
#   'retweet': [],
#   'user_name': 'Shegunmike',
#   'likes': [],
#   'tweet_id': 400733984725803008,
#   'user_id': 210780494},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377407,
#   'retweet': [],
#   'user_name': 'Gooners_Africa',
#   'likes': [],
#   'tweet_id': 400734008851451904,
#   'user_id': 475798208},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377436,
#   'retweet': [],
#   'user_name': 'AmGRINDA_AJANLA',
#   'likes': [],
#   'tweet_id': 400734127814492162,
#   'user_id': 139158379},
#  {'reply': [],
#   'text': '#bbc VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1dqR3VN ',
#   'created_at': 1384377447,
#   'retweet': [],
#   'user_name': 'SagarSingh1985',
#   'likes': [],
#   'tweet_id': 400734176866885633,
#   'user_id': 1922935801},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377448,
#   'retweet': [],
#   'user_name': 'Braa_Kusi',
#   'likes': [],
#   'tweet_id': 400734181421891585,
#   'user_id': 174215533},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp7fWD ',
#   'created_at': 1384377451,
#   'retweet': [],
#   'user_name': 'mr_____mr',
#   'likes': [],
#   'tweet_id': 400734192410972160,
#   'user_id': 1024667179},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377457,
#   'retweet': [],
#   'user_name': 'GbemiSweech',
#   'likes': [],
#   'tweet_id': 400734216867954688,
#   'user_id': 1464140689},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377459,
#   'retweet': [],
#   'user_name': 'LeumasDaBoss',
#   'likes': [],
#   'tweet_id': 400734226389016576,
#   'user_id': 381429581},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377473,
#   'retweet': [],
#   'user_name': '_Ayomide_',
#   'likes': [],
#   'tweet_id': 400734283293138945,
#   'user_id': 722625452},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377478,
#   'retweet': [],
#   'user_name': 'Jbabs09',
#   'likes': [],
#   'tweet_id': 400734305497804800,
#   'user_id': 1332293520},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said ... http://bbc.in/1cp6nkS  .. from BBC',
#   'created_at': 1384377480,
#   'retweet': [],
#   'user_name': 'QcName1',
#   'likes': [],
#   'tweet_id': 400734314481987584,
#   'user_id': 1614842300},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1dqRy2c ',
#   'created_at': 1384377622,
#   'retweet': [],
#   'user_name': 'myfirsthome',
#   'likes': [],
#   'tweet_id': 400734909783760896,
#   'user_id': 22135995},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said th... http://bbc.in/1cp6nkS  @bbcworld',
#   'created_at': 1384377623,
#   'retweet': [],
#   'user_name': 'newselleven',
#   'likes': [],
#   'tweet_id': 400734914779168768,
#   'user_id': 859446558},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1cp6nkS ',
#   'created_at': 1384377624,
#   'retweet': [],
#   'user_name': '_KingMel',
#   'likes': [],
#   'tweet_id': 400734920227565568,
#   'user_id': 80855613},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377628,
#   'retweet': [],
#   'user_name': 'JaluCok',
#   'likes': [],
#   'tweet_id': 400734936279171072,
#   'user_id': 518267218},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1MHl ',
#   'created_at': 1384377727,
#   'retweet': [],
#   'user_name': 'ebusiness_books',
#   'likes': [],
#   'tweet_id': 400735350819024896,
#   'user_id': 103921167},
#  {'reply': [],
#   'text': '#VIDEO: Winfrey: The Butler, racism and Obama #American broadcaster and actre http://whnieuws.nl/?p=15821 ',
#   'created_at': 1384377733,
#   'retweet': [],
#   'user_name': 'whnieuws',
#   'likes': [],
#   'tweet_id': 400735377071558656,
#   'user_id': 1709459880},
#  {'reply': [],
#   'text': 'U.S. VIDEO: Winfrey: The Butler, racism and Obama: American broad http://www.bhaskar.tv/video-winfrey-the-butler-racism-and-obama-american-broad-2/ …',
#   'created_at': 1384377837,
#   'retweet': [],
#   'user_name': 'flashnewsportal',
#   'likes': [],
#   'tweet_id': 400735811827949568,
#   'user_id': 201024231},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384377983,
#   'retweet': [],
#   'user_name': 'johnmicol3',
#   'likes': [],
#   'tweet_id': 400736424116232192,
#   'user_id': 131514784},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama - BBC News: BBC NewsOprah Winfrey: The Butler, racism and ObamaBBC NewsAmerican broadcast...',
#   'created_at': 1384378125,
#   'retweet': [],
#   'user_name': 'agapitoleslie',
#   'likes': [],
#   'tweet_id': 400737021657763840,
#   'user_id': 1720572685},
#  {'reply': [],
#   'text': '"VIDEO: Winfrey: The Butler, racism and Obama" by "" at BBC News http://ift.tt/HyBfFs ',
#   'created_at': 1384378125,
#   'retweet': [],
#   'user_name': 'QuackMooPowNews',
#   'likes': [],
#   'tweet_id': 400737019854614528,
#   'user_id': 2185947770},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384378269,
#   'retweet': [],
#   'user_name': 'dattblaze',
#   'likes': [],
#   'tweet_id': 400737623678783488,
#   'user_id': 377898604},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384378272,
#   'retweet': [],
#   'user_name': 'ECO4ALL2YOU',
#   'likes': [],
#   'tweet_id': 400737634571390976,
#   'user_id': 123974444},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://adf.ly/ZHPwO ',
#   'created_at': 1384378278,
#   'retweet': [],
#   'user_name': 'shahrukhre',
#   'likes': [],
#   'tweet_id': 400737661062619136,
#   'user_id': 176451895},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://adf.ly/ZHPxK ',
#   'created_at': 1384378283,
#   'retweet': [],
#   'user_name': 'W____News',
#   'likes': [],
#   'tweet_id': 400737680838754304,
#   'user_id': 896766074},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://adf.ly/ZHPz7 ',
#   'created_at': 1384378291,
#   'retweet': [],
#   'user_name': 'Heatingnewsss',
#   'likes': [],
#   'tweet_id': 400737714053451776,
#   'user_id': 508503207},
#  {'reply': [],
#   'text': '#TeamFollowBack VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1T9y  #AutoFollowback',
#   'created_at': 1384378295,
#   'retweet': [],
#   'user_name': 'RidhoHnf',
#   'likes': [],
#   'tweet_id': 400737730776158210,
#   'user_id': 437417506},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/18t5chy ',
#   'created_at': 1384378298,
#   'retweet': [],
#   'user_name': 'Srce_of_Errors',
#   'likes': [],
#   'tweet_id': 400737744898375681,
#   'user_id': 80828078},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there was a ... http://bbc.in/1cp6nkS ',
#   'created_at': 1384378299,
#   'retweet': [],
#   'user_name': 'BhebyFaze',
#   'likes': [],
#   'tweet_id': 400737749151408128,
#   'user_id': 1118573270},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama - BBC News',
#   'created_at': 1384378335,
#   'retweet': [],
#   'user_name': 'OprahHD',
#   'likes': [],
#   'tweet_id': 400737899114553344,
#   'user_id': 840054650},
#  {'reply': [],
#   'text': 'Powerful lady as ever! BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384378359,
#   'retweet': [],
#   'user_name': 'indutnt',
#   'likes': [],
#   'tweet_id': 400737999182245888,
#   'user_id': 387893673},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378495,
#   'retweet': [],
#   'user_name': 'ALarisaeka',
#   'likes': [],
#   'tweet_id': 400738570203181058,
#   'user_id': 789020936},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378499,
#   'retweet': [],
#   'user_name': 'Dzarotsoekamti',
#   'likes': [],
#   'tweet_id': 400738588138016768,
#   'user_id': 930216295},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378501,
#   'retweet': [],
#   'user_name': 'popyanjasia',
#   'likes': [],
#   'tweet_id': 400738597742981120,
#   'user_id': 993313789},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378505,
#   'retweet': [],
#   'user_name': 'almhafanessa',
#   'likes': [],
#   'tweet_id': 400738615073857536,
#   'user_id': 965898852},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378507,
#   'retweet': [],
#   'user_name': 'panjulajgoer',
#   'likes': [],
#   'tweet_id': 400738624053862400,
#   'user_id': 964162118},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378510,
#   'retweet': [],
#   'user_name': 'intanmaria__',
#   'likes': [],
#   'tweet_id': 400738633272930304,
#   'user_id': 965901050},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378512,
#   'retweet': [],
#   'user_name': 'DiniMeiske',
#   'likes': [],
#   'tweet_id': 400738642563317760,
#   'user_id': 964401932},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378519,
#   'retweet': [],
#   'user_name': 'bebhdulls',
#   'likes': [],
#   'tweet_id': 400738670409306112,
#   'user_id': 802582129},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378521,
#   'retweet': [],
#   'user_name': 'Tatapratama_',
#   'likes': [],
#   'tweet_id': 400738679083106304,
#   'user_id': 802150255},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEniQ9  #SEBHEUPDATE',
#   'created_at': 1384378526,
#   'retweet': [],
#   'user_name': 'bungahartita',
#   'likes': [],
#   'tweet_id': 400738702638329856,
#   'user_id': 964398085},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEnfUB  #SEBHEUPDATE',
#   'created_at': 1384378529,
#   'retweet': [],
#   'user_name': 'dyacllue',
#   'likes': [],
#   'tweet_id': 400738716043337728,
#   'user_id': 929501875},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1bEniQ9  #SEBHEUPDATE',
#   'created_at': 1384378532,
#   'retweet': [],
#   'user_name': 'nidanuraida_',
#   'likes': [],
#   'tweet_id': 400738725111422976,
#   'user_id': 807326594},
#  {'reply': [],
#   'text': 'RT @SEBHEUPDATE: VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1cp6nkS  #SEBHEUPDATE',
#   'created_at': 1384378540,
#   'retweet': [],
#   'user_name': 'rnmmm_',
#   'likes': [],
#   'tweet_id': 400738761065000960,
#   'user_id': 791998387},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Xm5 ',
#   'created_at': 1384378655,
#   'retweet': [],
#   'user_name': 'SlowestPoison',
#   'likes': [],
#   'tweet_id': 400739243711922176,
#   'user_id': 323685593},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Y1Y ',
#   'created_at': 1384378669,
#   'retweet': [],
#   'user_name': 'pascaluhie',
#   'likes': [],
#   'tweet_id': 400739299571671040,
#   'user_id': 1193910625},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://dlvr.it/4K1Y8j ',
#   'created_at': 1384378675,
#   'retweet': [],
#   'user_name': 'TheSansfaroukNG',
#   'likes': [],
#   'tweet_id': 400739324775251968,
#   'user_id': 160444233},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey… http://goo.gl/FkTek ',
#   'created_at': 1384378760,
#   'retweet': [],
#   'user_name': 'phillipsmovil',
#   'likes': [],
#   'tweet_id': 400739685020237824,
#   'user_id': 130914903},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384380247,
#   'retweet': [],
#   'user_name': 'KandiceBryan',
#   'likes': [],
#   'tweet_id': 400745921131991040,
#   'user_id': 119476626},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384380263,
#   'retweet': [],
#   'user_name': 'BBCSanaSafi',
#   'likes': ['585952595'],
#   'tweet_id': 400745985543901184,
#   'user_id': 56995827},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384380713,
#   'retweet': [],
#   'user_name': 'frost_vivienne',
#   'likes': [],
#   'tweet_id': 400747875405025280,
#   'user_id': 1301898476},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384381299,
#   'retweet': [],
#   'user_name': 'EchangeVirtuel',
#   'likes': [],
#   'tweet_id': 400750330482135040,
#   'user_id': 1265989352},
#  {'reply': [],
#   'text': 'From BBC VIDEO: Winfrey: The Butler, racism and Obama - American broadcaster and actress Oprah Winfrey said there ... http://ow.ly/2Brm5N ',
#   'created_at': 1384382274,
#   'retweet': [],
#   'user_name': 'Digital_TLT',
#   'likes': [],
#   'tweet_id': 400754421224976384,
#   'user_id': 1497636434},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama - American broadcaster and actress Oprah Winfrey said there was a who... http://ow.ly/2BrlGv ',
#   'created_at': 1384382375,
#   'retweet': [],
#   'user_name': 'SwiftehkNews',
#   'likes': [],
#   'tweet_id': 400754844992282624,
#   'user_id': 1438450512},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1dr6CwG ',
#   'created_at': 1384382586,
#   'retweet': [],
#   'user_name': 'CyG_society',
#   'likes': [],
#   'tweet_id': 400755731168645120,
#   'user_id': 167311019},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1dr6CwG ',
#   'created_at': 1384382587,
#   'retweet': [],
#   'user_name': 'CyG_US',
#   'likes': [],
#   'tweet_id': 400755735190986753,
#   'user_id': 153057180},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1dr6CwG ',
#   'created_at': 1384382587,
#   'retweet': [],
#   'user_name': 'CyG_celebrities',
#   'likes': [],
#   'tweet_id': 400755733370662912,
#   'user_id': 152186323},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://bbc.in/1dr6CwG ',
#   'created_at': 1384382588,
#   'retweet': [],
#   'user_name': 'CyG_videos',
#   'likes': [],
#   'tweet_id': 400755737153900544,
#   'user_id': 135094406},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384383046,
#   'retweet': [],
#   'user_name': 'bhuvanapriyaa',
#   'likes': [],
#   'tweet_id': 400757658602307584,
#   'user_id': 108918073},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama - VIDEO interview via @bbcnews http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384383244,
#   'retweet': [],
#   'user_name': 'PennyCrook',
#   'likes': [],
#   'tweet_id': 400758491997954048,
#   'user_id': 26986847},
#  {'reply': [],
#   'text': '#icametwice VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said there w...  @onedirslaytion',
#   'created_at': 1384383416,
#   'retweet': [],
#   'user_name': 'poxojode',
#   'likes': [],
#   'tweet_id': 400759211207831553,
#   'user_id': 1534267009},
#  {'reply': [],
#   'text': '#Oprah on what Americans see but hardly talk about RT@BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384383882,
#   'retweet': [],
#   'user_name': 'smugera',
#   'likes': [],
#   'tweet_id': 400761166613327872,
#   'user_id': 144995994},
#  {'reply': [],
#   'text': 'VIDEO: Winfrey: The Butler, racism and Obama http://goo.gl/4L9oh7 ',
#   'created_at': 1384384806,
#   'retweet': [],
#   'user_name': 'newsoneservice',
#   'likes': [],
#   'tweet_id': 400765043434074112,
#   'user_id': 148450312},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384385086,
#   'retweet': [],
#   'user_name': 'RichardLewis33',
#   'likes': [],
#   'tweet_id': 400766215846522880,
#   'user_id': 299676120},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384386592,
#   'retweet': [],
#   'user_name': 'RochesterFilm',
#   'likes': [],
#   'tweet_id': 400772533575630848,
#   'user_id': 750083864},
#  {'reply': [],
#   'text': 'http://j.mp/HNxI6P  Winfrey: The Butler, racism and Obama',
#   'created_at': 1384391112,
#   'retweet': [],
#   'user_name': 'LibyaSketch',
#   'likes': [],
#   'tweet_id': 400791489455747073,
#   'user_id': 589870669},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384392966,
#   'retweet': [],
#   'user_name': 'OgbeniDipo',
#   'likes': [],
#   'tweet_id': 400799266865553408,
#   'user_id': 153529375},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384396905,
#   'retweet': [],
#   'user_name': 'thebigfelaAde',
#   'likes': [],
#   'tweet_id': 400815789969666048,
#   'user_id': 46538380},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama - http://m.bbc.co.uk/news/entertainment-arts-24934979?ocid=socialflow_twitter_bbcworld …',
#   'created_at': 1384397243,
#   'retweet': [],
#   'user_name': 'DMT_Nation',
#   'likes': [],
#   'tweet_id': 400817207330234368,
#   'user_id': 603267720},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384398492,
#   'retweet': [],
#   'user_name': 'abenebo',
#   'likes': [],
#   'tweet_id': 400822444371349505,
#   'user_id': 28657011},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384400586,
#   'retweet': [],
#   'user_name': 'eishamarjara',
#   'likes': [],
#   'tweet_id': 400831226992279553,
#   'user_id': 122793254},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384401416,
#   'retweet': [],
#   'user_name': 'Dilargachew',
#   'likes': [],
#   'tweet_id': 400834711003492353,
#   'user_id': 444487199},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384402146,
#   'retweet': [],
#   'user_name': 'blogdohamilton',
#   'likes': [],
#   'tweet_id': 400837770509172736,
#   'user_id': 1638898405},
#  {'reply': [],
#   'text': 'U.S. BBC News - Oprah Winfrey: The Butler, racism and Obama http: http://www.bhaskar.tv/bbc-news-oprah-winfrey-the-butler-racism-and-obama-http-12/ …',
#   'created_at': 1384403357,
#   'retweet': [],
#   'user_name': 'flashnewsportal',
#   'likes': [],
#   'tweet_id': 400842849794527232,
#   'user_id': 201024231},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http: http://www.bhaskar.tv/bbc-news-oprah-winfrey-the-butler-racism-and-obama-http-12/ …',
#   'created_at': 1384403360,
#   'retweet': [],
#   'user_name': 'flashnewsportal',
#   'likes': [],
#   'tweet_id': 400842863312777217,
#   'user_id': 201024231},
#  {'reply': [],
#   'text': 'BBC breathless @Oprah\'s feet despite her racist claim that Obama opponents r racists!? "The Butler, racism and Obama" http://goo.gl/2ZKlvj ',
#   'created_at': 1384407889,
#   'retweet': [],
#   'user_name': 'edfranks',
#   'likes': [],
#   'tweet_id': 400861860754255872,
#   'user_id': 23923352},
#  {'reply': [],
#   'text': '@TheButler- BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …. looking forward to watching it!',
#   'created_at': 1384411372,
#   'retweet': [],
#   'user_name': 'wairimugitau8',
#   'likes': [],
#   'tweet_id': 400876468487454720,
#   'user_id': 370958129},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384415663,
#   'retweet': [],
#   'user_name': 'cjacobkuria',
#   'likes': [],
#   'tweet_id': 400894464287191040,
#   'user_id': 279458880},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384417663,
#   'retweet': [],
#   'user_name': 'FionaMontW',
#   'likes': [],
#   'tweet_id': 400902852408655873,
#   'user_id': 424195149},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384417674,
#   'retweet': [],
#   'user_name': 'ElizObihFrank',
#   'likes': [],
#   'tweet_id': 400902901268111361,
#   'user_id': 18548253},
#  {'reply': [],
#   'text': '[ bbc News]: VIDEO: Winfrey: The Butler, racism and Obama: American broadcaster and actress Oprah Winfrey said... http://bbc.in/1cp6nkS ',
#   'created_at': 1384419287,
#   'retweet': [],
#   'user_name': 'openda0409',
#   'likes': [],
#   'tweet_id': 400909666693038080,
#   'user_id': 32658080},
#  {'reply': [],
#   'text': 'BBC News - #Oprah #Winfrey: The Butler, #racism and #Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 … finally someone else says it as it is',
#   'created_at': 1384423595,
#   'retweet': [],
#   'user_name': 'SangwaniNkhwazi',
#   'likes': [],
#   'tweet_id': 400927733003198464,
#   'user_id': 1092620652},
#  {'reply': [],
#   'text': 'U.S. Oprah Winfrey: The Butler, racism and Obama http://t.co/OeAu http://www.bhaskar.tv/oprah-winfrey-the-butler-racism-and-obama-http-t-co-oeau/ …',
#   'created_at': 1384424665,
#   'retweet': [],
#   'user_name': 'flashnewsportal',
#   'likes': [],
#   'tweet_id': 400932222129037312,
#   'user_id': 201024231},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama http://t.co/OeAu http://www.bhaskar.tv/oprah-winfrey-the-butler-racism-and-obama-http-t-co-oeau/ …',
#   'created_at': 1384424673,
#   'retweet': [],
#   'user_name': 'flashnewsportal',
#   'likes': [],
#   'tweet_id': 400932256845275137,
#   'user_id': 201024231},
#  {'reply': [],
#   'text': 'U.S. BBC News - #Oprah #Winfrey: The Butler, #racism and #Obama h http://www.bhaskar.tv/bbc-news-oprah-winfrey-the-butler-racism-and-obama-h/ …',
#   'created_at': 1384424863,
#   'retweet': [],
#   'user_name': 'flashnewsportal',
#   'likes': [],
#   'tweet_id': 400933052525731840,
#   'user_id': 201024231},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384426039,
#   'retweet': [{'favorite_count': 0,
#     'coordinates': None,
#     'retweeted_status': {'favorite_count': 1,
#      'coordinates': None,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'urls': [{'indices': [55, 77],
#         'expanded_url': 'http://www.bbc.co.uk/news/entertainment-arts-24934979',
#         'url': 'http://t.co/lRnlHmVTco',
#         'display_url': 'bbc.co.uk/news/entertain…'}],
#       'user_mentions': []},
#      'contributors': None,
#      'truncated': False,
#      'retweeted': False,
#      'user': {'default_profile': False,
#       'default_profile_image': False,
#       'geo_enabled': True,
#       'is_translation_enabled': False,
#       'protected': False,
#       'verified': False,
#       'screen_name': 'caravaggio12',
#       'time_zone': None,
#       'description': "Scot, OU Study Langs -  Garg 'nuair dhùisgear (Fierce when roused)\nMusic,books,sport,outdoors,cuisine,chess,photography,history,art&travel!Politics!",
#       'utc_offset': None,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/419164886661599233/Vq2NLe9H_normal.jpeg',
#       'followers_count': 3290,
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_text_color': '333333',
#       'created_at': 'Sat May 09 14:20:27 +0000 2009',
#       'favourites_count': 98657,
#       'profile_use_background_image': True,
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'id_str': '38859818',
#       'notifications': False,
#       'translator_type': 'none',
#       'following': False,
#       'url': None,
#       'lang': 'en',
#       'listed_count': 491,
#       'profile_link_color': 'B30000',
#       'contributors_enabled': False,
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_background_color': 'EBD6C3',
#       'is_translator': False,
#       'entities': {'description': {'urls': []}},
#       'location': 'South West England',
#       'statuses_count': 284713,
#       'follow_request_sent': False,
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38859818/1398243513',
#       'profile_background_tile': True,
#       'id': 38859818,
#       'has_extended_profile': True,
#       'friends_count': 4988,
#       'name': 'Alf - #FBPE #ABTV',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/419164886661599233/Vq2NLe9H_normal.jpeg'},
#      'favorited': False,
#      'retweet_count': 6,
#      'geo': None,
#      'in_reply_to_screen_name': None,
#      'place': None,
#      'id_str': '400937984834293760',
#      'in_reply_to_status_id': None,
#      'in_reply_to_user_id': None,
#      'created_at': 'Thu Nov 14 10:47:19 +0000 2013',
#      'lang': 'en',
#      'source': '<a href="https://dev.twitter.com/docs/tfw" rel="nofollow">Twitter for Websites</a>',
#      'in_reply_to_status_id_str': None,
#      'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://t.co/lRnlHmVTco',
#      'id': 400937984834293760,
#      'in_reply_to_user_id_str': None,
#      'possibly_sensitive': True,
#      'is_quote_status': False},
#     'contributors': None,
#     'truncated': False,
#     'retweeted': False,
#     'user': {'default_profile': True,
#      'default_profile_image': False,
#      'geo_enabled': False,
#      'is_translation_enabled': False,
#      'protected': False,
#      'verified': False,
#      'screen_name': 'PrincesseCqui',
#      'time_zone': None,
#      'description': 'Grand intérêt pour ce petit monde...Compte de secours de @MoniezC♡ I unfollow all unfollow me !',
#      'utc_offset': None,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/3320093451/2f8b92b72a46003f2fed1778b8f2d8ea_normal.jpeg',
#      'followers_count': 798,
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_text_color': '333333',
#      'created_at': 'Thu Feb 28 16:18:30 +0000 2013',
#      'favourites_count': 2496,
#      'profile_use_background_image': True,
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'id_str': '1227877826',
#      'notifications': False,
#      'translator_type': 'none',
#      'following': False,
#      'url': None,
#      'lang': 'fr',
#      'listed_count': 19,
#      'profile_link_color': '1DA1F2',
#      'contributors_enabled': False,
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_background_color': 'C0DEED',
#      'is_translator': False,
#      'entities': {'description': {'urls': []}},
#      'location': '',
#      'statuses_count': 22729,
#      'follow_request_sent': False,
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1227877826/1362070876',
#      'profile_background_tile': False,
#      'id': 1227877826,
#      'has_extended_profile': False,
#      'friends_count': 1036,
#      'name': 'Chantal Moniez',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3320093451/2f8b92b72a46003f2fed1778b8f2d8ea_normal.jpeg'},
#     'favorited': False,
#     'retweet_count': 6,
#     'geo': None,
#     'in_reply_to_screen_name': None,
#     'place': None,
#     'id_str': '400958386571059200',
#     'in_reply_to_status_id': None,
#     'in_reply_to_user_id': None,
#     'created_at': 'Thu Nov 14 12:08:23 +0000 2013',
#     'lang': 'en',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'indices': [73, 95],
#        'expanded_url': 'http://www.bbc.co.uk/news/entertainment-arts-24934979',
#        'url': 'http://t.co/lRnlHmVTco',
#        'display_url': 'bbc.co.uk/news/entertain…'}],
#      'user_mentions': [{'indices': [3, 16],
#        'id': 38859818,
#        'id_str': '38859818',
#        'name': 'Alf - #FBPE #ABTV',
#        'screen_name': 'caravaggio12'}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id_str': None,
#     'text': 'RT @caravaggio12: BBC News - Oprah Winfrey: The Butler, racism and Obama http://t.co/lRnlHmVTco',
#     'id': 400958386571059200,
#     'in_reply_to_user_id_str': None,
#     'possibly_sensitive': False,
#     'is_quote_status': False},
#    {'favorite_count': 0,
#     'coordinates': None,
#     'retweeted_status': {'favorite_count': 1,
#      'coordinates': None,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'urls': [{'indices': [55, 77],
#         'expanded_url': 'http://www.bbc.co.uk/news/entertainment-arts-24934979',
#         'url': 'http://t.co/lRnlHmVTco',
#         'display_url': 'bbc.co.uk/news/entertain…'}],
#       'user_mentions': []},
#      'contributors': None,
#      'truncated': False,
#      'retweeted': False,
#      'user': {'default_profile': False,
#       'default_profile_image': False,
#       'geo_enabled': True,
#       'is_translation_enabled': False,
#       'protected': False,
#       'verified': False,
#       'screen_name': 'caravaggio12',
#       'time_zone': None,
#       'description': "Scot, OU Study Langs -  Garg 'nuair dhùisgear (Fierce when roused)\nMusic,books,sport,outdoors,cuisine,chess,photography,history,art&travel!Politics!",
#       'utc_offset': None,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/419164886661599233/Vq2NLe9H_normal.jpeg',
#       'followers_count': 3290,
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_text_color': '333333',
#       'created_at': 'Sat May 09 14:20:27 +0000 2009',
#       'favourites_count': 98657,
#       'profile_use_background_image': True,
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'id_str': '38859818',
#       'notifications': False,
#       'translator_type': 'none',
#       'following': False,
#       'url': None,
#       'lang': 'en',
#       'listed_count': 491,
#       'profile_link_color': 'B30000',
#       'contributors_enabled': False,
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_background_color': 'EBD6C3',
#       'is_translator': False,
#       'entities': {'description': {'urls': []}},
#       'location': 'South West England',
#       'statuses_count': 284713,
#       'follow_request_sent': False,
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38859818/1398243513',
#       'profile_background_tile': True,
#       'id': 38859818,
#       'has_extended_profile': True,
#       'friends_count': 4988,
#       'name': 'Alf - #FBPE #ABTV',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/419164886661599233/Vq2NLe9H_normal.jpeg'},
#      'favorited': False,
#      'retweet_count': 6,
#      'geo': None,
#      'in_reply_to_screen_name': None,
#      'place': None,
#      'id_str': '400937984834293760',
#      'in_reply_to_status_id': None,
#      'in_reply_to_user_id': None,
#      'created_at': 'Thu Nov 14 10:47:19 +0000 2013',
#      'lang': 'en',
#      'source': '<a href="https://dev.twitter.com/docs/tfw" rel="nofollow">Twitter for Websites</a>',
#      'in_reply_to_status_id_str': None,
#      'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://t.co/lRnlHmVTco',
#      'id': 400937984834293760,
#      'in_reply_to_user_id_str': None,
#      'possibly_sensitive': True,
#      'is_quote_status': False},
#     'contributors': None,
#     'truncated': False,
#     'retweeted': False,
#     'user': {'default_profile': True,
#      'default_profile_image': False,
#      'geo_enabled': False,
#      'is_translation_enabled': False,
#      'protected': False,
#      'verified': False,
#      'screen_name': 'MoniezC2',
#      'time_zone': None,
#      'description': 'La Liberté est le pouvoir de disposer de notre attention. Malebranche.   Résidence secondaire de @MoniezC',
#      'utc_offset': None,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/344513261569163934/9c94f5ba492cedab898bb4f401866584_normal.jpeg',
#      'followers_count': 1434,
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_text_color': '333333',
#      'created_at': 'Wed Jun 20 16:06:50 +0000 2012',
#      'favourites_count': 3981,
#      'profile_use_background_image': True,
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'id_str': '613631874',
#      'notifications': False,
#      'translator_type': 'none',
#      'following': False,
#      'url': None,
#      'lang': 'fr',
#      'listed_count': 17,
#      'profile_link_color': '1DA1F2',
#      'contributors_enabled': False,
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_background_color': 'C0DEED',
#      'is_translator': False,
#      'entities': {'description': {'urls': []}},
#      'location': '',
#      'statuses_count': 27261,
#      'follow_request_sent': False,
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/613631874/1371050315',
#      'profile_background_tile': False,
#      'id': 613631874,
#      'has_extended_profile': False,
#      'friends_count': 1603,
#      'name': 'Moniez Chantal',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/344513261569163934/9c94f5ba492cedab898bb4f401866584_normal.jpeg'},
#     'favorited': False,
#     'retweet_count': 6,
#     'geo': None,
#     'in_reply_to_screen_name': None,
#     'place': None,
#     'id_str': '400952707609272320',
#     'in_reply_to_status_id': None,
#     'in_reply_to_user_id': None,
#     'created_at': 'Thu Nov 14 11:45:49 +0000 2013',
#     'lang': 'en',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'indices': [73, 95],
#        'expanded_url': 'http://www.bbc.co.uk/news/entertainment-arts-24934979',
#        'url': 'http://t.co/lRnlHmVTco',
#        'display_url': 'bbc.co.uk/news/entertain…'}],
#      'user_mentions': [{'indices': [3, 16],
#        'id': 38859818,
#        'id_str': '38859818',
#        'name': 'Alf - #FBPE #ABTV',
#        'screen_name': 'caravaggio12'}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id_str': None,
#     'text': 'RT @caravaggio12: BBC News - Oprah Winfrey: The Butler, racism and Obama http://t.co/lRnlHmVTco',
#     'id': 400952707609272320,
#     'in_reply_to_user_id_str': None,
#     'possibly_sensitive': False,
#     'is_quote_status': False},
#    {'favorite_count': 0,
#     'coordinates': None,
#     'retweeted_status': {'favorite_count': 1,
#      'coordinates': None,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'urls': [{'indices': [55, 77],
#         'expanded_url': 'http://www.bbc.co.uk/news/entertainment-arts-24934979',
#         'url': 'http://t.co/lRnlHmVTco',
#         'display_url': 'bbc.co.uk/news/entertain…'}],
#       'user_mentions': []},
#      'contributors': None,
#      'truncated': False,
#      'retweeted': False,
#      'user': {'default_profile': False,
#       'default_profile_image': False,
#       'geo_enabled': True,
#       'is_translation_enabled': False,
#       'protected': False,
#       'verified': False,
#       'screen_name': 'caravaggio12',
#       'time_zone': None,
#       'description': "Scot, OU Study Langs -  Garg 'nuair dhùisgear (Fierce when roused)\nMusic,books,sport,outdoors,cuisine,chess,photography,history,art&travel!Politics!",
#       'utc_offset': None,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/419164886661599233/Vq2NLe9H_normal.jpeg',
#       'followers_count': 3290,
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_text_color': '333333',
#       'created_at': 'Sat May 09 14:20:27 +0000 2009',
#       'favourites_count': 98657,
#       'profile_use_background_image': True,
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'id_str': '38859818',
#       'notifications': False,
#       'translator_type': 'none',
#       'following': False,
#       'url': None,
#       'lang': 'en',
#       'listed_count': 491,
#       'profile_link_color': 'B30000',
#       'contributors_enabled': False,
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_background_color': 'EBD6C3',
#       'is_translator': False,
#       'entities': {'description': {'urls': []}},
#       'location': 'South West England',
#       'statuses_count': 284713,
#       'follow_request_sent': False,
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38859818/1398243513',
#       'profile_background_tile': True,
#       'id': 38859818,
#       'has_extended_profile': True,
#       'friends_count': 4988,
#       'name': 'Alf - #FBPE #ABTV',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/419164886661599233/Vq2NLe9H_normal.jpeg'},
#      'favorited': False,
#      'retweet_count': 6,
#      'geo': None,
#      'in_reply_to_screen_name': None,
#      'place': None,
#      'id_str': '400937984834293760',
#      'in_reply_to_status_id': None,
#      'in_reply_to_user_id': None,
#      'created_at': 'Thu Nov 14 10:47:19 +0000 2013',
#      'lang': 'en',
#      'source': '<a href="https://dev.twitter.com/docs/tfw" rel="nofollow">Twitter for Websites</a>',
#      'in_reply_to_status_id_str': None,
#      'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://t.co/lRnlHmVTco',
#      'id': 400937984834293760,
#      'in_reply_to_user_id_str': None,
#      'possibly_sensitive': True,
#      'is_quote_status': False},
#     'contributors': None,
#     'truncated': False,
#     'retweeted': False,
#     'user': {'default_profile': True,
#      'default_profile_image': False,
#      'geo_enabled': False,
#      'is_translation_enabled': False,
#      'protected': False,
#      'verified': False,
# ...
#   'retweet': [],
#   'user_name': 'dribj',
#   'likes': [],
#   'tweet_id': 402639798684225536,
#   'user_id': 34984875},
#  {'reply': [],
#   'text': '@ananavarro Implying that Oprah used the Butler to tie in with Obama & Racism is wrong. Obama deals with Racism Everyday!  and SO DO YOU!',
#   'created_at': 1384833409,
#   'retweet': [],
#   'user_name': 'sweet_revenge3',
#   'likes': [],
#   'tweet_id': 402646618089865216,
#   'user_id': 63243885},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1384840081,
#   'retweet': [],
#   'user_name': 'CoolLukeHH',
#   'likes': [],
#   'tweet_id': 402674604801413120,
#   'user_id': 188632216},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama: http://youtu.be/9v9LbnBQ9aE  via @youtube',
#   'created_at': 1384894250,
#   'retweet': [],
#   'user_name': 'MrFriendWilkins',
#   'likes': [],
#   'tweet_id': 402901805014601729,
#   'user_id': 405659907},
#  {'reply': [{'text': '@GraniteShoals @tjoy7 @YouTube http://www.southparkstudios.com/clips/155235/oprahs-minge-has-a-gun …',
#     'created_at': '1385012306',
#     'id': 403396966622560256,
#     'retweets': 0,
#     'username': 'Rowanes',
#     'in_reply_to_status_id': 403197891906260994,
#     'user': 88370617}],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama: http://youtu.be/9v9LbnBQ9aE  via @youtube',
#   'created_at': 1384964843,
#   'retweet': [{'favorite_count': 0,
#     'coordinates': None,
#     'retweeted_status': {'favorite_count': 0,
#      'coordinates': None,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'urls': [{'indices': [56, 78],
#         'url': 'http://t.co/aMDfo5vRGS',
#         'expanded_url': 'http://youtu.be/9v9LbnBQ9aE',
#         'display_url': 'youtu.be/9v9LbnBQ9aE'}],
#       'user_mentions': [{'indices': [83, 91],
#         'id': 10228272,
#         'id_str': '10228272',
#         'name': 'YouTube',
#         'screen_name': 'YouTube'}]},
#      'in_reply_to_user_id': None,
#      'truncated': False,
#      'retweeted': False,
#      'user': {'default_profile': False,
#       'default_profile_image': False,
#       'is_translation_enabled': False,
#       'protected': False,
#       'statuses_count': 3613,
#       'verified': False,
#       'screen_name': 'GraniteShoals',
#       'time_zone': None,
#       'description': 'Army Brat, Navy Wife, Mother of 2, Grandmother of 3, God fearing.  Love my country.  CONSERVATIVE',
#       'utc_offset': None,
#       'location': 'Texas',
#       'geo_enabled': False,
#       'profile_text_color': '333333',
#       'created_at': 'Sat Oct 03 15:21:28 +0000 2009',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#       'favourites_count': 422,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000457225768/d2b7064f3c8b6957af93865660010c61_normal.png',
#       'profile_use_background_image': True,
#       'profile_sidebar_fill_color': 'EFEFEF',
#       'id_str': '79484921',
#       'notifications': False,
#       'translator_type': 'none',
#       'following': False,
#       'url': None,
#       'lang': 'en',
#       'listed_count': 15,
#       'follow_request_sent': False,
#       'contributors_enabled': False,
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_background_color': '0F1212',
#       'followers_count': 787,
#       'entities': {'description': {'urls': []}},
#       'is_translator': False,
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79484921/1379527071',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#       'profile_background_tile': True,
#       'id': 79484921,
#       'profile_link_color': '00998C',
#       'has_extended_profile': False,
#       'friends_count': 1140,
#       'name': 'DJ Mullinix',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000457225768/d2b7064f3c8b6957af93865660010c61_normal.png'},
#      'favorited': False,
#      'retweet_count': 1,
#      'geo': None,
#      'in_reply_to_screen_name': None,
#      'place': None,
#      'id_str': '403197891906260994',
#      'in_reply_to_status_id': None,
#      'contributors': None,
#      'created_at': 'Wed Nov 20 16:27:23 +0000 2013',
#      'lang': 'en',
#      'source': '<a href="https://dev.twitter.com/docs/tfw" rel="nofollow">Twitter for Websites</a>',
#      'in_reply_to_status_id_str': None,
#      'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama: http://t.co/aMDfo5vRGS via @youtube',
#      'id': 403197891906260994,
#      'in_reply_to_user_id_str': None,
#      'possibly_sensitive': False,
#      'is_quote_status': False},
#     'in_reply_to_user_id': None,
#     'truncated': False,
#     'retweeted': False,
#     'user': {'default_profile': False,
#      'default_profile_image': False,
#      'is_translation_enabled': False,
#      'protected': False,
#      'statuses_count': 122714,
#      'verified': False,
#      'screen_name': 'tjoy7',
#      'time_zone': None,
#      'description': 'Libertarian ☮️ wife~mom~daughter\nrealtor 🏡music 🎼 run 🏃\u200d♀️\ngarden 🌷#Trump 🇺🇸 #MAGA 🚂  \n#TCOT #PJNET',
#      'utc_offset': None,
#      'location': 'Austin, Texas',
#      'geo_enabled': False,
#      'profile_text_color': '362720',
#      'created_at': 'Tue Jun 16 15:52:41 +0000 2009',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#      'favourites_count': 10891,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000469779337/993cae5b974b0a04236add13e3fc3653_normal.png',
#      'profile_use_background_image': True,
#      'profile_sidebar_fill_color': 'E5507E',
#      'id_str': '47657632',
#      'notifications': False,
#      'translator_type': 'none',
#      'following': False,
#      'url': None,
#      'lang': 'en',
#      'listed_count': 247,
#      'follow_request_sent': False,
#      'contributors_enabled': False,
#      'profile_sidebar_border_color': 'CC3366',
#      'profile_background_color': 'FF6699',
#      'followers_count': 20572,
#      'entities': {'description': {'urls': []}},
#      'is_translator': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/47657632/1357008805',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_tile': False,
#      'id': 47657632,
#      'profile_link_color': 'B40B44',
#      'has_extended_profile': False,
#      'friends_count': 20364,
#      'name': 'Tami Joyce',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000469779337/993cae5b974b0a04236add13e3fc3653_normal.png'},
#     'favorited': False,
#     'retweet_count': 1,
#     'geo': None,
#     'in_reply_to_screen_name': None,
#     'place': None,
#     'id_str': '403396410365575168',
#     'in_reply_to_status_id': None,
#     'contributors': None,
#     'created_at': 'Thu Nov 21 05:36:13 +0000 2013',
#     'lang': 'en',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'indices': [75, 97],
#        'url': 'http://t.co/aMDfo5vRGS',
#        'expanded_url': 'http://youtu.be/9v9LbnBQ9aE',
#        'display_url': 'youtu.be/9v9LbnBQ9aE'}],
#      'user_mentions': [{'indices': [3, 17],
#        'id': 79484921,
#        'id_str': '79484921',
#        'name': 'DJ Mullinix',
#        'screen_name': 'GraniteShoals'},
#       {'indices': [102, 110],
#        'id': 10228272,
#        'id_str': '10228272',
#        'name': 'YouTube',
#        'screen_name': 'YouTube'}]},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id_str': None,
#     'text': 'RT @GraniteShoals: BBC News - Oprah Winfrey: The Butler, racism and Obama: http://t.co/aMDfo5vRGS via @youtube',
#     'id': 403396410365575168,
#     'in_reply_to_user_id_str': None,
#     'possibly_sensitive': False,
#     'is_quote_status': False}],
#   'user_name': 'GraniteShoals',
#   'likes': [],
#   'tweet_id': 403197891906260994,
#   'user_id': 79484921},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama: http://youtu.be/9v9LbnBQ9aE  via @youtube',
#   'created_at': 1384971175,
#   'retweet': [],
#   'user_name': 'CockneyRebelle',
#   'likes': [],
#   'tweet_id': 403224449656180736,
#   'user_id': 1620584648},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://youtu.be/9v9LbnBQ9aE ',
#   'created_at': 1384997155,
#   'retweet': [],
#   'user_name': 'bromoore',
#   'likes': [],
#   'tweet_id': 403333418210975745,
#   'user_id': 28313639},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://youtu.be/9v9LbnBQ9aE ',
#   'created_at': 1385001302,
#   'retweet': [],
#   'user_name': 'uthinkithink',
#   'likes': [],
#   'tweet_id': 403350814481068034,
#   'user_id': 222850010},
#  {'reply': [],
#   'text': "Watch this video: Oprah Winfrey_ The Butler, racism and Obama  http://landing.newsinc.com/shared/video.html?freewheel=91424 … (This is why going across aisle doesn't work)2-VISCOUS",
#   'created_at': 1385011421,
#   'retweet': [],
#   'user_name': 'Barbielk1',
#   'likes': [],
#   'tweet_id': 403393255888277504,
#   'user_id': 493743627},
#  {'reply': [{'text': "@TransracialPare  WHAT'S GOING ON WITH RACISM? FIND OUT  - http://www.drturi.com/20141016-universal-arian-draconis-predictions/ … RTPls",
#     'created_at': '1385074974',
#     'id': 403659814439370752,
#     'retweets': 0,
#     'username': 'drturi',
#     'in_reply_to_status_id': 403655736460206081,
#     'user': 37713818}],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1385074001,
#   'retweet': [],
#   'user_name': 'TransracialPare',
#   'likes': [],
#   'tweet_id': 403655736460206081,
#   'user_id': 966379278},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama: http://youtu.be/Fx3NgPQ18jg  via @youtube Like Boehner,Rand,Cruz,Mitch?',
#   'created_at': 1385080224,
#   'retweet': [],
#   'user_name': 'Ross_7_7',
#   'likes': [],
#   'tweet_id': 403681834501799936,
#   'user_id': 380693277},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://bbc.in/1aF2ZzB ',
#   'created_at': 1385089248,
#   'retweet': [],
#   'user_name': 'DingiMasuku',
#   'likes': [],
#   'tweet_id': 403719685738217474,
#   'user_id': 342092117},
#  {'reply': [],
#   'text': 'Checking out "BBC News - Oprah Winfrey: The Butler, racism and Obama" on WACPtv: http://ning.it/1bMKg7J ',
#   'created_at': 1385092085,
#   'retweet': [],
#   'user_name': 'fridaykaley',
#   'likes': [],
#   'tweet_id': 403731586509570048,
#   'user_id': 126704993},
#  {'reply': [],
#   'text': 'Oprah, Obama, and a Racism Dodge: In Britain to foster her film The Butler, Oprah Winfrey gave an speak to a... http://dlvr.it/4MnS4S  ◄',
#   'created_at': 1385121986,
#   'retweet': [],
#   'user_name': 'NFLEquipment',
#   'likes': [],
#   'tweet_id': 403857000527720449,
#   'user_id': 1152704046},
#  {'reply': [],
#   'text': 'Jonah Goldberg: Oprah Winfrey, Barack Obama and the racism edge: In Britain to promote her film "The Butler," ... http://bit.ly/1bZByVT ',
#   'created_at': 1385188952,
#   'retweet': [],
#   'user_name': 'nvdaily',
#   'likes': [],
#   'tweet_id': 404137874435497984,
#   'user_id': 15099017},
#  {'reply': [],
#   'text': 'Jonah Goldberg: Oprah Winfrey, Barack Obama and the racism edge: In Britain to promote her film "The Butler," ... http://bit.ly/1cfBkYT ',
#   'created_at': 1385273710,
#   'retweet': [],
#   'user_name': 'foxnews4America',
#   'likes': [],
#   'tweet_id': 404493375497584640,
#   'user_id': 263382615},
#  {'reply': [],
#   'text': '"They just have to die." Oprah got real! --> "Oprah Winfrey: The Butler, racism and Obama" http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1386015444,
#   'retweet': [],
#   'user_name': 'saunique',
#   'likes': [],
#   'tweet_id': 407604433413865472,
#   'user_id': 146524387},
#  {'reply': [],
#   'text': 'BBC News   Oprah Winfrey  The Butler, racism and Obama: http://youtu.be/xkBkyzai2jw  via @youtube',
#   'created_at': 1392717515,
#   'retweet': [],
#   'user_name': 'DMV77',
#   'likes': [],
#   'tweet_id': 435714954822303744,
#   'user_id': 120026648},
#  {'reply': [],
#   'text': 'Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1394456449,
#   'retweet': [],
#   'user_name': 'RochesterFilm',
#   'likes': [],
#   'tweet_id': 443008575904821248,
#   'user_id': 750083864},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.co.uk/news/entertainment-arts-24934979 …',
#   'created_at': 1466091303,
#   'retweet': [],
#   'user_name': 'zionelledove',
#   'likes': [],
#   'tweet_id': 743466930368094210,
#   'user_id': 2922774670},
#  {'reply': [],
#   'text': '@Oprah  Oprah Winfrey: The Butler, racism and Obama - http://BBC.com  - November 13th, 2013  "American broad',
#   'created_at': 1515444626,
#   'retweet': [],
#   'user_name': 'egameboss',
#   'likes': [],
#   'tweet_id': 950469768997474306,
#   'user_id': 611215787},
#  {'reply': [],
#   'text': 'Oprah Winfrey The Butler, racism and Obama https://youtu.be/4TM1EiqHT_0  via @YouTube',
#   'created_at': 1515455259,
#   'retweet': [],
#   'user_name': 'Linda_Thomas_RN',
#   'likes': ['2705810407'],
#   'tweet_id': 950514366402703360,
#   'user_id': 16439260},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama  \n http://www.bbc.com/news/av/entertainment-arts-24934979/oprah-winfrey-the-butler-racism-and-obama …',
#   'created_at': 1515462069,
#   'retweet': [],
#   'user_name': 'MrUSA10',
#   'likes': [],
#   'tweet_id': 950542932431421440,
#   'user_id': 4465545972},
#  {'reply': [],
#   'text': 'Winfrey: The Butler, racism and Obama - BBC News http://www.bbc.com/news/av/entertainment-arts-24934979/oprah-winfrey-the-butler-racism-and-obama …',
#   'created_at': 1515467455,
#   'retweet': [],
#   'user_name': 'freelancer1a2b',
#   'likes': [],
#   'tweet_id': 950565521237438464,
#   'user_id': 3068933499},
#  {'reply': [],
#   'text': "Sorry it's this one.  BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.com/news/av/entertainment-arts-24934979/oprah-winfrey-the-butler-racism-and-obama …",
#   'created_at': 1515514518,
#   'retweet': [],
#   'user_name': 'CurttS',
#   'likes': [],
#   'tweet_id': 950762919091896320,
#   'user_id': 68983932},
#  {'reply': [],
#   'text': "BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.com/news/av/entertainment-arts-24934979/oprah-winfrey-the-butler-racism-and-obama@jasonsfolly-I … don't care about melanin. Reverse racism is wrong too.",
#   'created_at': 1515744331,
#   'retweet': [],
#   'user_name': 'ln419',
#   'likes': [],
#   'tweet_id': 951726824450641920,
#   'user_id': 229275456},
#  {'reply': [{'text': 'Reverse racism won\'t work either. You aren\'t going to "kill off all the old white people marinated in it" and be POTUS.',
#     'created_at': '1515745687',
#     'id': 951732510349815808,
#     'retweets': 0,
#     'username': 'ln419',
#     'in_reply_to_status_id': 951731207527682048,
#     'user': 229275456}],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.com/news/av/entertainment-arts-24934979/oprah-winfrey-the-butler-racism-and-obama … @jasonsfolly',
#   'created_at': 1515745376,
#   'retweet': [],
#   'user_name': 'ln419',
#   'likes': [],
#   'tweet_id': 951731207527682048,
#   'user_id': 229275456},
#  {'reply': [],
#   'text': 'Oprah Winfrey  The Butler, racism and Obama https://youtu.be/1w2pNuEd5xs  via @YouTube',
#   'created_at': 1516227400,
#   'retweet': [],
#   'user_name': 'RobinLi19793914',
#   'likes': [],
#   'tweet_id': 953752962307731456,
#   'user_id': 866800326128566273},
#  {'reply': [],
#   'text': 'BBC News - Oprah Winfrey: The Butler, racism and Obama http://www.bbc.com/news/av/entertainment-arts-24934979/oprah-winfrey-the-butler-racism-and-obama …',
#   'created_at': 1517634555,
#   'retweet': [],
#   'user_name': 'Dailey_Peg',
#   'likes': [],
#   'tweet_id': 959654995502288896,
#   'user_id': 3071850757},
#  {'reply': [],
#   'text': 'Winfrey: The Butler, racism and Obama ',
#   'created_at': 1527816358,
#   'retweet': [],
#   'user_name': 'Ihavealottosay',
#   'likes': [],
#   'tweet_id': 1002360574624313345,
#   'user_id': 22941113}]

# %%
tweet_data = []
pageSize=1

#//Page 1
fakenews_items = fakenews_datatable.find({}).limit(100);

for fake_newsItem in fakenews_items:
    print(f"{fake_newsItem['id']} ---> {fake_newsItem['text_content']['text']}")
# Out:
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-20-180b98abd629> in <module>()
#       5 fakenews_items = fakenews_datatable.find({}).limit(100);
#       6
# ----> 7 for fake_newsItem in fakenews_items:
#       8     print(f"{fake_newsItem['id']} ---> {fake_newsItem['text_content']['text']}")
#       9
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1102                                   self.__session,
#    1103                                   self.__collection.database.client)
# -> 1104             self.__send_message(q)
#    1105         elif self.__id:  # Get More
#    1106             if self.__limit:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     929             try:
#     930                 response = client._send_message_with_response(
# --> 931                     operation, exhaust=self.__exhaust, address=self.__address)
#     932                 self.__address = response.address
#     933                 if self.__exhaust:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _send_message_with_response(self, operation, exhaust, address)
#    1143             self.__all_credentials,
#    1144             self._event_listeners,
# -> 1145             exhaust)
#    1146
#    1147     def _reset_on_error(self, server, func, *args, **kwargs):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _reset_on_error(self, server, func, *args, **kwargs)
#    1154         """
#    1155         try:
# -> 1156             return func(*args, **kwargs)
#    1157         except NetworkTimeout:
#    1158             # The socket has been closed. Don't reset the server.
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\server.py in send_message_with_response(self, operation, set_slave_okay, all_credentials, listeners, exhaust)
#     104             try:
#     105                 sock_info.send_message(data, max_doc_size)
# --> 106                 reply = sock_info.receive_message(request_id)
#     107             except Exception as exc:
#     108                 if publish:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\pool.py in receive_message(self, request_id)
#     610                                    self.max_message_size)
#     611         except BaseException as error:
# --> 612             self._raise_connection_failure(error)
#     613
#     614     def _raise_if_not_writable(self, unacknowledged):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\pool.py in receive_message(self, request_id)
#     608         try:
#     609             return receive_message(self.sock, request_id,
# --> 610                                    self.max_message_size)
#     611         except BaseException as error:
#     612             self._raise_connection_failure(error)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\network.py in receive_message(sock, request_id, max_message_size)
#     182     if length > max_message_size:
#     183         raise ProtocolError("Message length (%r) is larger than server max "
# --> 184                             "message size (%r)" % (length, max_message_size))
#     185     if op_code == 2012:
#     186         op_code, _, compressor_id = _UNPACK_COMPRESSION_HEADER(
#
# ProtocolError: Message length (20611297) is larger than server max message size (4194304)

# %%
#fakenews_items = fakenews_datatable.find({}).limit(20);

#fakenews_datatable.aggregate( [ { "$unwind": "$tags" },  { "count": "$tweets" } ] ).limit(10)

items = fakenews_datatable.aggregate([{
  "$project": {
      "_id": "$_id",
      "id":"$id",
      "text_content":"$text_content.$text",
      "tweetCount": { "$size": "$tweets" }
  }
    
}]);

df = pd.DataFrame(list(items))
df.head()

# %%
df = df.sort_values(by='tweetCount',ascending=False)

# %%
df.head(10)
# Out:
#                           _id               id  tweetCount
# 84   5c34465ae8a490580c567e7b  politifact15018        1141
# 9    5c3445ffe8a490580c567e46  politifact14259         975
# 35   5c34461499023e6294754497  politifact14839         963
# 63   5c34463de8a490580c567e71  politifact13589         827
# 38   5c34462699023e62947544ac  politifact15004         430
# 30   5c344615f839832ff86827f0  politifact13854         376
# 19   5c34461144925f59105fd04f  politifact14238         352
# 102  5c34466599023e62947544bb  politifact15334         333
# 5    5c3445ffe8a490580c567e41  politifact15201         329
# 103  5c34466599023e62947544bc  politifact15048         296

# %%
df2=df.head(10)
df2['news_title']=""
for index,row in df2.iterrows():
    df2.set_value(index,'news_title',fakenews_datatable.find_one({"id":row["id"]})['text_content']['title'])

df2.head()
# Out:
# C:\Users\chami\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chami\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
#                          _id               id  tweetCount  \
# 84  5c34465ae8a490580c567e7b  politifact15018        1141
# 9   5c3445ffe8a490580c567e46  politifact14259         975
# 35  5c34461499023e6294754497  politifact14839         963
# 63  5c34463de8a490580c567e71  politifact13589         827
# 38  5c34462699023e62947544ac  politifact15004         430
#
#                                            news_title
# 84  Smoking In Cars With Children Is Illegal Start...
# 9   Bumble Bee Foods charged after man cooked with...
# 35  Morgue employee cremated by mistake while taki...
# 63  Pope Francis To Followers: “Koran And Holy Bib...
# 38  NFL Lawyer, Who Claimed Super Bowl Is ‘Rigged’...

# %%
df2.to_csv("top_tweeted.csv")

# %%
politifacts=fakenews_datatable.find_one({"id":"politifact15048"})
print(politifacts['text_content']['title'])
# Out:
# Trump Declares Globalist Soros As “National Security Threat”…Using Obama’s 2014 Executive Order

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
for tweet in politifacts['tweets']:

        twitter_data=api.get_status(tweet['tweet_id'])
        print(twitter_data.text)
        print(twitter_data.user.location)
        print(datetime.utcfromtimestamp(tweet['created_at']).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Trump Declares Globalist Soros As "National Security Threat"...Using Obama's 2014 Executive Order
# https://t.co/JKEYt8RnCu
# Arrest &amp; prosecute
# ΜΟΛΩΝ ΛΑΒΕ Texas
# 2017-01-30 19:24:12
# Trump Declares Globalist Soros As "National Security Threat"...Using Obama's 2014 Executive Order https://t.co/RQ9ELtiByb
#
# 2017-01-30 20:37:53
# Trump Declares Globalist Soros As “National Security Threat”…Using Obama’s 2014 Executive Order https://t.co/GeDay7EjYl
# Port St. Lucie, FL
# 2017-01-30 20:39:46
# Trump Declares Globalist Soros As “National Security Threat”…Using Obama’s 2014 Executive Order https://t.co/qRUxBBXKij
# Hoover ,AL
# 2017-01-30 20:47:49
# Trump Declares Globalist Soros As "National Security Threat"...Using Obama's 2014 Executive Order https://t.co/9IQapbndZM
# abuja
# 2017-01-30 20:51:21
# https://t.co/37QuX65oQ6
# TRUMP DECLARES GLOBALIST SOROS AS “NATIONAL SECURITY THREAT”…USING OBAMA’S 2014 EXECUTIVE ORDER
# Texas, USA
# 2017-01-30 21:17:22
# Trump Declares Globalist Soros As "National Security Threat"...Using Obama's 2014 Executive Order https://t.co/KRWSShxyD3
# Sugar Land, TX
# 2017-01-30 21:22:38
# Trump Declares Globalist Soros As “National Security Threat”…Using Obama’s 2014 Executive Order https://t.co/WuGDLGaj8B
#
# 2017-01-30 21:28:12
# Trump Declares Globalist Soros As “National Security Threat”…Using Obama’s 2014 Executive Order https://t.co/70OquJ9HcM
# hanford,ca
# 2017-01-30 21:34:34
# Trump Declares Globalist Soros As “National Security Threat”…Using Obama’s 2014 Executive Order https://t.co/i8dvReEZwZ
#
# 2017-01-30 21:35:24
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-12-7e6bbc711fa8> in <module>()
#       1 for tweet in politifacts['tweets']:
#       2
# ----> 3         twitter_data=api.get_status(tweet['tweet_id'])
#       4         print(twitter_data.text)
#       5         print(twitter_data.user.location)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\tweepy\binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: [{'code': 144, 'message': 'No status found with that ID.'}]

# %%
df2
for index,row in df2.iterrows():
    print(row['id'])
# Out:
# politifact15018
# politifact14259
# politifact14839
# politifact13589
# politifact15004
# politifact13854
# politifact14238
# politifact15334
# politifact15201
# politifact15048

# %%
twitter_data_list = []

for index,row in df2.iterrows():
   
    politifacts=fakenews_datatable.find_one({"id":row["id"]})
    print(politifacts['text_content']['title'])
    
    for tweet in politifacts['tweets']:
        twitter_data_dic = {}
        try:
            twitter_data_dic['id']=row['id']
            twitter_data_dic['title']=politifacts['text_content']['title']
            
            twitter_data=api.get_status(tweet['tweet_id'])
            print(twitter_data.text)
            print(twitter_data.user.location)
            print(datetime.utcfromtimestamp(tweet['created_at']).strftime('%Y-%m-%d %H:%M:%S'))
            print(twitter_data.user.screen_name)
            twitter_data_dic['twitter_text']=twitter_data.text
            twitter_data_dic['twitter_location']=twitter_data.user.location
            twitter_data_dic['twitter_time']=datetime.utcfromtimestamp(tweet['created_at']).strftime('%Y-%m-%d %H:%M:%S')
            twitter_data_dic['twitter_user']=twitter_data.user.screen_name
            
            twitter_data_list.append(twitter_data_dic)
            db.twitter_data_combined.insert(twitter_data_dic)
       
        except tweepy.RateLimitError:
            print("rate limit exceeded")
            time.sleep(60 * 15)
            continue
        except:
            print("Unexpected error:")
# Out:
# Smoking In Cars With Children Is Illegal Starting January 30, 2018
# rate limit exceeded
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-14-bb85650440a6> in <module>()
#      13
# ---> 14             twitter_data=api.get_status(tweet['tweet_id'])
#      15             print(twitter_data.text)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     249         else:
# --> 250             return method.execute()
#     251
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\tweepy\binder.py in execute(self)
#     231                 if is_rate_limit_error_message(error_msg):
# --> 232                     raise RateLimitError(error_msg, resp)
#     233                 else:
#
# RateLimitError: [{'message': 'Rate limit exceeded', 'code': 88}]
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bb85650440a6> in <module>()
#      27         except tweepy.RateLimitError:
#      28             print("rate limit exceeded")
# ---> 29             time.sleep(60 * 15)
#      30             continue
#      31         except:
#
# NameError: name 'time' is not defined

# %%
combined_data = pd.DataFrame(twitter_data_list)
combined_data
# Out:
#                   id                                              title  \
# 0    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 1    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 2    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 3    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 4    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 5    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 6    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 7    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 8    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 9    politifact15018  Smoking In Cars With Children Is Illegal Start...
# 10   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 11   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 12   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 13   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 14   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 15   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 16   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 17   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 18   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 19   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 20   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 21   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 22   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 23   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 24   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 25   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 26   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 27   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 28   politifact15018  Smoking In Cars With Children Is Illegal Start...
# 29   politifact15018  Smoking In Cars With Children Is Illegal Start...
# ..               ...                                                ...
# 645  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 646  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 647  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 648  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 649  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 650  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 651  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 652  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 653  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 654  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 655  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 656  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 657  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 658  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 659  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 660  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 661  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 662  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 663  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 664  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 665  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 666  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 667  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 668  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 669  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 670  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 671  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 672  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 673  politifact15018  Smoking In Cars With Children Is Illegal Start...
# 674  politifact15018  Smoking In Cars With Children Is Illegal Start...
#
#                    twitter_location  \
# 0                             World
# 1                              Ohio
# 2                    Louisiana, USA
# 3
# 4                   Baton Rouge, LA
# 5
# 6                              Ohio
# 7               Charlottesville, VA
# 8
# 9                           Houston
# 10                Wellston Missouri
# 11                       KINZERS PA
# 12                          at home
# 13                       New Jersey
# 14
# 15                     Scituate, MA
# 16        Body in Nyc-Mind in Pluto
# 17
# 18              30.344898,-81.71757
# 19                           Global
# 20               Corning, NY    USA
# 21                          Indiana
# 22                              usa
# 23                   Wilmington, NC
# 24
# 25   Syracuse and Surrounding areas
# 26
# 27                   Clarksville Tn
# 28                          Memphis
# 29
# ..                              ...
# 645                    lexington ky
# 646                     connecticut
# 647                      Gilbert AZ
# 648                     Montreal,QC
# 649               Columbus Georgia
# 650                          mumbai
# 651                         Como NC
# 652            brampton ont canada
# 653                    Portland, OR
# 654                        Michigan
# 655               LasVegas WinCity
# 656                   charlotte N.C
# 657                    Alabama, USA
# 658        Bruce, Mississippi 38915
# 659                West Babylon, NY
# 660
# 661                              NC
# 662                        Edmonton
# 663                 Los Angeles, CA
# 664
# 665                   long beach ca
# 666                Valley Forge, PA
# 667  Parkhurst Jo'burg South Africa
# 668                   United States
# 669                 San Antonio, TX
# 670         lincoln, nh white mnts
# 671            some where out there
# 672           Pueblo West, CO 81007
# 673
# 674                        Caraquet
#
#                                           twitter_text         twitter_time  \
# 0    Smoking In Cars With Children Is Illegal Start...  2018-02-03 19:13:08
# 1    Smoking In Cars With Children Is Illegal Start...  2018-02-04 14:23:14
# 2    Smoking In Cars With Children Is Illegal Start...  2018-02-05 23:52:22
# 3    Smoking In Cars With Children Is Illegal Start...  2018-02-06 01:19:39
# 4    Smoking In Cars With Children Is Illegal Start...  2018-02-06 01:28:08
# 5    Smoking In Cars With Children Is Illegal Start...  2018-02-06 01:38:27
# 6    Smoking In Cars With Children Is Illegal Start...  2018-02-06 02:52:22
# 7    Smoking In Cars With Children Is Illegal Start...  2018-02-06 05:13:49
# 8    Smoking In Cars With Children Is Illegal Start...  2018-02-06 11:34:02
# 9    Smoking In Cars With Children Is Illegal Start...  2018-02-06 12:45:22
# 10   Smoking In Cars With Children Is Illegal Start...  2018-02-06 12:50:09
# 11   Smoking In Cars With Children Is Illegal Start...  2018-02-06 14:28:04
# 12   Smoking In Cars With Children Is Illegal Start...  2018-02-06 15:27:16
# 13   Smoking In Cars With Children Is Illegal Start...  2018-02-06 15:59:28
# 14   Smoking In Cars With Children Is Illegal Start...  2018-02-06 16:26:17
# 15   Smoking In Cars With Children Is Illegal Start...  2018-02-06 16:34:46
# 16   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:02:07
# 17   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:17:05
# 18   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:27:55
# 19   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:43:52
# 20   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:47:44
# 21   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:53:25
# 22   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:53:44
# 23   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:55:14
# 24   Smoking In Cars With Children Is Illegal Start...  2018-02-06 17:57:30
# 25   Smoking In Cars With Children Is Illegal Start...  2018-02-06 18:02:11
# 26   Smoking In Cars With Children Is Illegal Start...  2018-02-06 18:12:01
# 27   Smoking In Cars With Children Is Illegal Start...  2018-02-06 18:27:46
# 28   Smoking In Cars With Children Is Illegal Start...  2018-02-06 18:28:33
# 29   Smoking In Cars With Children Is Illegal Start...  2018-02-06 18:41:48
# ..                                                 ...                  ...
# 645  Smoking In Cars With Children Is Illegal Start...  2018-02-10 21:12:00
# 646  Smoking In Cars With Children Is Illegal Start...  2018-02-10 21:39:00
# 647  Smoking In Cars With Children Is Illegal Start...  2018-02-10 22:00:53
# 648  Smoking In Cars With Children Is Illegal Start...  2018-02-10 22:07:31
# 649  Smoking In Cars With Children Is Illegal Start...  2018-02-10 22:11:34
# 650  Smoking In Cars With Children Is Illegal Start...  2018-02-10 22:34:39
# 651  Smoking In Cars With Children Is Illegal Start...  2018-02-10 22:47:01
# 652  Smoking In Cars With Children Is Illegal Start...  2018-02-10 23:03:56
# 653  Smoking In Cars With Children Is Illegal Start...  2018-02-10 23:10:11
# 654  Smoking In Cars With Children Is Illegal Start...  2018-02-11 00:24:13
# 655  Smoking In Cars With Children Is Illegal Start...  2018-02-11 00:26:07
# 656  Smoking In Cars With Children Is Illegal Start...  2018-02-11 00:26:17
# 657  Smoking In Cars With Children Is Illegal Start...  2018-02-11 00:46:43
# 658  Smoking In Cars With Children Is Illegal Start...  2018-02-11 00:53:17
# 659  Smoking In Cars With Children Is Illegal Start...  2018-02-11 01:22:04
# 660  Smoking In Cars With Children Is Illegal Start...  2018-02-11 01:41:55
# 661  Smoking In Cars With Children Is Illegal Start...  2018-02-11 01:55:44
# 662  Smoking In Cars With Children Is Illegal Start...  2018-02-11 02:43:13
# 663  Smoking In Cars With Children Is Illegal Start...  2018-02-11 03:09:53
# 664  Smoking In Cars With Children Is Illegal Start...  2018-02-11 04:20:45
# 665  Smoking In Cars With Children Is Illegal Start...  2018-02-11 04:34:37
# 666  Smoking In Cars With Children Is Illegal Start...  2018-02-11 05:01:38
# 667  Smoking In Cars With Children Is Illegal Start...  2018-02-11 07:33:05
# 668  Smoking In Cars With Children Is Illegal Start...  2018-02-11 07:34:16
# 669  Smoking In Cars With Children Is Illegal Start...  2018-02-11 07:58:17
# 670  Smoking In Cars With Children Is Illegal Start...  2018-02-11 08:29:37
# 671  Smoking In Cars With Children Is Illegal Start...  2018-02-11 09:32:25
# 672  Smoking In Cars With Children Is Illegal Start...  2018-02-11 13:23:31
# 673  Smoking In Cars With Children Is Illegal Start...  2018-02-11 14:13:32
# 674  Smoking In Cars With Children Is Illegal Start...  2018-02-11 14:19:22
#
#         twitter_user
# 0    BestAmazingTwts
# 1         Ohjobfairs
# 2         JECcupcake
# 3      garmentsgrace
# 4     ElijahFreeman2
# 5     jkupdegraff426
# 6          elovebug7
# 7          crazy4dmb
# 8       KekChrysalis
# 9        Pinkychelle
# 10         heavysilk
# 11        dymples100
# 12       lillyann231
# 13      mariapksells
# 14       Phuckk_Youu
# 15   suchaluckiegirl
# 16   lifewithbrandon
# 17              bj54
# 18          BBEMUZIC
# 19          MiaaTIpX
# 20   William37796179
# 21          Tabemily
# 22   michaelgenetarl
# 23           VHibler
# 24       VipMidSouth
# 25    ClossonClosson
# 26       VerticalWMG
# 27        RebaEvitts
# 28   londonfoggmusic
# 29       GayleKwapis
# ..               ...
# 645      bobbyyoung2
# 646     ptadvocate4u
# 647   hotarizonadzrt
# 648        SSF_IIIHS
# 649       Vampire706
# 650       r_divyanka
# 651      TonyAllison
# 652       MajorDjx2c
# 653           kmii00
# 654      JoelleGwynn
# 655          DJValet
# 656    TNOFaceStudio
# 657        RNFIsaiah
# 658  GRIFFINSGUNSHOP
# 659      AlwaysAtAum
# 660       dhtown2000
# 661       GinaBezael
# 662  Mayanparadoxmex
# 663        missrogan
# 664       kmaria1943
# 665        so_p_easy
# 666     LyniseWalton
# 667   MartyduPlessis
# 668     CityBoutique
# 669  monicagarciads1
# 670      forestlouie
# 671        imagine45
# 672         loybanks
# 673    ChippyTrids62
# 674    moniachiasson
#
# [675 rows x 6 columns]

# %%
combined_data.to_json(orient='records')
# Out:
# '[{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"World","twitter_text":"Smoking In Cars With Children Is Illegal Starting  January 30, 2018 https:\\/\\/t.co\\/0GMGFKYUkG","twitter_time":"2018-02-03 19:13:08","twitter_user":"BestAmazingTwts"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"Ohio","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/InClWrusQB","twitter_time":"2018-02-04 14:23:14","twitter_user":"Ohjobfairs"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"Louisiana, USA","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/1Tcb1OZE3e","twitter_time":"2018-02-05 23:52:22","twitter_user":"JECcupcake"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/sGZ3Gvfeim","twitter_time":"2018-02-06 01:19:39","twitter_user":"garmentsgrace"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"Baton Rouge, LA","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/S5pmf9FhZs","twitter_time":"2018-02-06 01:28:08","twitter_user":"ElijahFreeman2"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/JzzbQxZ0IF","twitter_time":"2018-02-06 01:38:27","twitter_user":"jkupdegraff426"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"Ohio","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/DfuWzH3F0I via @LoveThisPic_com","twitter_time":"2018-02-06 02:52:22","twitter_user":"elovebug7"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"Charlottesville, VA","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/psE0Qr8GoX via @LoveThisPic_com","twitter_time":"2018-02-06 05:13:49","twitter_user":"crazy4dmb"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/nzgZaiBv5v","twitter_time":"2018-02-06 11:34:02","twitter_user":"KekChrysalis"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"Houston","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/S5MzXh3TGq","twitter_time":"2018-02-06 12:45:22","twitter_user":"Pinkychelle"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"Wellston Missouri","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/H7Moc422Qr","twitter_time":"2018-02-06 12:50:09","twitter_user":"heavysilk"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"KINZERS PA","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30, 2018 https:\\/\\/t.co\\/Id7YT6xToi","twitter_time":"2018-02-06 14:28:04","twitter_user":"dymples100"},{"id":"politifact15018","title":"Smoking In Cars With Children Is Illegal Starting January 30, 2018","twitter_location":"at home","twitter_text":"Smoking In Cars With Children Is Illegal Starting January 30,  ...

# %%
with open('data.json', 'w') as outfile:
    json.dump(combined_data.to_json(orient='records'), outfile)

# %%
combined_data.to_csv("data.csv")
